# %%
user_age = int(input('Whar is your age? '))
if user_age <= 17:
    print ('You are still young, and needs parent consent.')
elif user_age == 18:
    print('Just the right age.')
else:
    print('You are old enough, you do not need parent consent.')
# Out:
# Whar is your age?  19
# You are old enough, you do not need parent consent.

# %% [raw]
# EXPLANATION TO THE CODE ABOVE AND DIFFERENCE BETWENN WHILE, IF, IF-ELSE, AND FOR LOOP:
#
# Certainly! Let's break down the differences between `while`, `if`, `if-else`, and `for loop` in simple terms, with examples and guidance on when to use each.
#
# ---
#
# ### 1. **`while` Loop**
# The `while` loop is used to repeat a block of code as long as a certain condition is true. It’s like saying, "Keep doing this until something changes."
#
# #### Example:
# ```python
# count = 0
# while count < 3:  # As long as count is less than 3
#     print("Hello!")
#     count += 1  # Increment count to eventually stop the loop
# ```
#
# #### Output:
# ```
# Hello!
# Hello!
# Hello!
# ```
#
# #### When to Use:
# - When you don't know beforehand how many times the loop should run.
# - When the loop depends on a condition that may change during execution (e.g., waiting for user input or monitoring a process).
#
# #### When Not to Use:
# - When you know exactly how many times the loop should run (use a `for` loop instead).
# - When the condition may never change, causing an infinite loop.
#
# ---
#
# ### 2. **`if` Statement**
# The `if` statement checks a condition and runs the code inside it only if the condition is true. It’s like saying, "Do this if this happens."
#
# #### Example:
# ```python
# age = 18
# if age >= 18:  # If the condition is true
#     print("You are eligible to vote.")
# ```
#
# #### Output:
# ```
# You are eligible to vote.
# ```
#
# #### When to Use:
# - To make decisions in your program.
# - When you need to execute a block of code only if a condition is true.
#
# #### When Not to Use:
# - When you need to handle multiple possibilities (use `if-else` or `if-elif-else`).
#
# ---
#
# ### 3. **`if-else` Statement**
# The `if-else` statement provides two options: one for when the condition is true, and another for when it’s false. It’s like saying, "Do this if this happens; otherwise, do that."
#
# #### Example:
# ```python
# age = 16
# if age >= 18:
#     print("You are eligible to vote.")
# else:
#     print("You are not eligible to vote.")
# ```
#
# #### Output:
# ```
# You are not eligible to vote.
# ```
#
# #### When to Use:
# - When you need to handle two possible outcomes.
# - When you want to provide an alternative action if the condition is false.
#
# #### When Not to Use:
# - When there are more than two possible outcomes (use `if-elif-else`).
#
# ---
#
# ### 4. **`for` Loop**
# The `for` loop is used to repeat a block of code for a fixed number of times or to go through a collection of items. It’s like saying, "Do this for every item in this group."
#
# #### Example:
# ```python
# for i in range(3):  # Loop 3 times (0, 1, 2)
#     print("Hello!")
# ```
#
# #### Output:
# ```
# Hello!
# Hello!
# Hello!
# ```
#
# #### Example with a Collection:
# ```python
# names = ["Alice", "Bob", "Charlie"]
# for name in names:  # Go through each name in the list
#     print(name)
# ```
#
# #### Output:
# ```
# Alice
# Bob
# Charlie
# ```
#
# #### When to Use:
# - When you know exactly how many times the loop should run.
# - When you want to iterate over a collection of items (e.g., a list or a range).
#
# #### When Not to Use:
# - When the loop depends on a condition rather than a fixed number of iterations (use a `while` loop).
#
# ---
#
# ### Key Differences and When to Use Each
# | **Feature**      | **`while`**                              | **`if`**                         | **`if-else`**                       | **`for`**                           |
# |-------------------|------------------------------------------|-----------------------------------|--------------------------------------|--------------------------------------|
# | **Purpose**       | Repeat as long as a condition is true    | Execute code if a condition is true | Handle two possible outcomes         | Repeat a block of code for a fixed number of times or items |
# | **Repetition**    | Yes                                      | No                                | No                                   | Yes                                 |
# | **Use Case**      | Dynamic repetition (e.g., user input)    | Single decision                  | Binary decision                     | Iterating over items or ranges      |
# | **Example**       | Loop while user input is invalid         | Check if age is 18+              | Check if age is 18+ or not          | Print all items in a list           |
#
# ---
#
# ### Real-Life Analogy
# - **`while` Loop:** Imagine you’re waiting for the rain to stop before going outside. You keep checking the weather until it stops raining.
# - **`if` Statement:** You decide to take an umbrella if it’s raining.
# - **`if-else` Statement:** You decide to take an umbrella if it’s raining; otherwise, you take sunglasses.
# - **`for` Loop:** You distribute flyers to every person in a room.
#
# ---
#
# Let me know if you need further clarification or examples!

# %%
user_age = int(input('Whar is your age? '))
if user_age <= 17:
    print ('You are still young, and needs parent consent.')
elif user_age == 18:
    print('Just the right age.')
else:
    print('You are old enough, you do not need parent consent.')
# Out:
# Whar is your age?  19
# You are old enough, you do not need parent consent.
