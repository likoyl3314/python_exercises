# %% [raw]
# define a FUNCTION, def Function:

# %%
def greet(name):
    return f'Hello {name}! How are you?'

print(greet('Michael'))

# %%
def fullName(firstName, lastName):
    combine = firstName + ' ' + lastName 
    return combine

combinedName = fullName('Michael', 'Tan')
print(combinedName)

# %%
def fullName(firstName, lastName, middleName=None):
    """
    Combines a first name, optional middle name, and last name into a full name.

    Parameters:
    firstName (str): The first name of the person.
    lastName (str): The last name of the person.
    middleName (str, optional): The middle name of the person.

    Returns:
    str: The full name in the format 'FirstName MiddleName LastName' or 'FirstName LastName'.
    """
    if not isinstance(firstName, str) or not isinstance(lastName, str):
        raise ValueError("Both firstName and lastName must be strings.")
    if middleName:
        return f"{firstName} {middleName} {lastName}"
    return f"{firstName} {lastName}"

# Example Usage
# combinedName = fullName("Michael", "Tan", "Garcia")
# print(combinedName)
# fullName("Michael", "Tan", "Garcia")
print(f'Your name is {fullName("Michael", "Tan", "Garcia")}.')

# %%
#allows input
def fullName():
    firstName = input("Enter your first name: ")
    lastName = input("Enter your last name: ")
    return f"{firstName} {lastName}"

combinedName = fullName()
print(combinedName)
print(fullName())

# %%
#THIS IS AN ERRONOUS CODE, EXPLANATION BELOW:
'''
Errors in the Code

    try Block Misuse:
        The try block is not followed by valid code directly. Instead, it contains the def statement, which is invalid. 
        You cannot define a function inside a try block in this manner.

    Indentation Issues:
        The def statement and the code following it are incorrectly indented. Proper indentation is critical in Python.

    Logical Flow:
        The try block is unnecessary here because input() does not raise a ValueError. The input needs to be validated 
        explicitly, not caught with try and except.

    Misplaced except:
        The except block is improperly indented and does not match the structure of the try block.

    Infinite Loop Logic:
        The while True loop is not effectively integrated with the get_full_name() function. It doesn’t ensure that 
        invalid input will prompt the user again.

'''

####
while True:
    try:
def get_full_name(first_name=None, last_name=None):
    """
    Returns the full name.
    If no arguments are provided, it prompts the user for input.
    """
    if first_name is None:
        first_name = input("Enter your first name: ").strip()
    if last_name is None:
        last_name = input("Enter your last name: ").strip()

    # Validate input (only letters allowed)
    if not first_name.isalpha() or not last_name.isalpha():
        print("Error: Names should only contain letters.")
        return None
    return f"{first_name} {last_name}"
 except ValueError:
         print('Error')

# Example usage
combined_name = get_full_name()
if combined_name:
    print(combined_name)

# Reuse the function with arguments
#print(get_full_name("Michael", "Tan"))

# %%
#THIS IS THE CORRECT CODE FOR ABOVE PROBLEM:

def get_full_name():
    """
    Returns the full name after validating user input.
    Prompts the user until valid names are entered.
    """
    while True:
        first_name = input("Enter your first name: ").strip()
        last_name = input("Enter your last name: ").strip()

        # Validate input (only letters allowed)
        if not first_name.isalpha() or not last_name.isalpha():
            print("Error: Names should only contain letters. Please try again.")
        else:
            return f"{first_name} {last_name}"


# Example usage
combined_name = get_full_name()
print(f"Your full name is: {combined_name}")

# %%
def fullName(firstName, lastName, middleName=None): #optional middle name
    firstName = input("Enter your first name: ")
    lastName = input("Enter your last name: ")
    middleName = input("Enter your middle name: ")
    return f"{firstName} {lastName}"
    """
    Combines a first name, optional middle name, and last name into a full name.

    Parameters:
    firstName (str): The first name of the person.
    lastName (str): The last name of the person.
    middleName (str, optional): The middle name of the person.

    Returns:
    str: The full name in the format 'FirstName MiddleName LastName' or 'FirstName LastName'.
    """
    if not isinstance(firstName, str) or not isinstance(lastName, str):
        raise ValueError("Both firstName and lastName must be strings.")
    if middleName:
        return f"{firstName} {middleName} {lastName}"
    return f"{firstName} {lastName}"

# Example Usage
combinedName = fullName("Michael", "Tan", "James")
print(combinedName)

'''
EXPLANATION:
Your code has several issues that prevent it from working correctly. Here's an analysis of the problems and a corrected version of the code.

Problems in the Code

    Redundant Input Statements:
        The firstName, lastName, and middleName parameters are provided as arguments, but they are overwritten by input() calls inside the function. This is inconsistent with the function's design, which expects arguments to be passed explicitly.

    Unreachable Code:
        The return statement (return f"{firstName} {lastName}") appears before the conditional block that checks for middleName. Once the return statement is executed, the function exits, and the rest of the code is never executed.

    Incorrect Docstring Placement:
        The docstring is placed after the first return statement, making it inaccessible as part of the function's metadata.

    Misuse of Optional Parameters:
        The middleName parameter is marked as optional but is always overwritten by input().

    Logic Issues:
        The function is not designed to handle cases where middleName is optional effectively.
'''

# %%
#THE CORRECT CODE ABOVE:

def fullName(firstName=None, lastName=None, middleName=None):
    """
    Combines a first name, optional middle name, and last name into a full name.

    Parameters:
    firstName (str, optional): The first name of the person. If not provided, the user will be prompted.
    lastName (str, optional): The last name of the person. If not provided, the user will be prompted.
    middleName (str, optional): The middle name of the person.

    Returns:
    str: The full name in the format 'FirstName MiddleName LastName' or 'FirstName LastName'.
    """
    # Prompt for firstName and lastName if not provided
    if firstName is None:
        firstName = input("Enter your first name: ").strip()
    if lastName is None:
        lastName = input("Enter your last name: ").strip()
    if middleName is None:
        middleName = input("Enter your middle name (leave blank if none): ").strip()

    # Validate inputs
    if not firstName.isalpha() or not lastName.isalpha() or (middleName and not middleName.isalpha()):
        raise ValueError("Names must only contain letters.")

    # Combine names
    if middleName:
        return f"{firstName} {middleName} {lastName}"
    return f"{firstName} {lastName}"


# Example Usage
try:
    combinedName = fullName()  # Prompts the user for input
    print(f"Your full name is: {combinedName}")
except ValueError as e:
    print(f"Error: {e}")

    """
    Explanation of Fixes

    Optional Parameters with Defaults:
        The firstName, lastName, and middleName parameters are optional, and the function will prompt the user only if they are not provided.

    Docstring Placement:
        The docstring is placed immediately after the def statement for proper documentation.

    Validation:
        Added a validation step to ensure that all names contain only letters.

    Logic Correction:
        The return statement now appears after the conditional block, ensuring the function handles all cases.

    Graceful Error Handling:
        The try block in the example usage ensures that the program handles invalid input gracefully.

    Key Improvements

    Clean Code: Clear separation of logic and input handling.
    User Flexibility: Allows users to provide input or pass arguments.
    Error Handling: Prevents invalid input from causing unexpected behavior.
    """

# %%
#WITH VALIDATION LOOP USING while True
def fullName():
    """
    Combines a first name, optional middle name, and last name into a full name.

    Prompts the user for input until valid data is provided.

    Returns:
    str: The full name in the format 'FirstName MiddleName LastName' or 'FirstName LastName'.
    """
    while True:
        # Prompt for first name
        firstName = input("Enter your first name: ").strip()
        if not firstName.isalpha():
            print("Error: First name must only contain letters. Please try again.")
            continue

        # Prompt for last name
        lastName = input("Enter your last name: ").strip()
        if not lastName.isalpha():
            print("Error: Last name must only contain letters. Please try again.")
            continue

        # Prompt for middle name (optional)
        middleName = input("Enter your middle name (leave blank if none): ").strip()
        if middleName and not middleName.isalpha():
            print("Error: Middle name must only contain letters. Please try again.")
            continue

        # If all inputs are valid, construct and return the full name
        if middleName:
            return f"{firstName} {middleName} {lastName}"
        return f"{firstName} {lastName}"


# Example Usage
print("Please provide your full name.")
full_name = fullName()
print(f"Your full name is: {full_name}")

# %%
    """
    EXPLANATION for the above codes:

    Why Adding the while True Loop Makes Sense

    1. The while True loop is a control mechanism that ensures the program keeps running until valid data is provided by the user. Without it, the program would exit after a single invalid input, which is not ideal in scenarios where valid input is required.
    Key Reasons for Using while True:

    2. Validation Loop:
        It allows the program to repeatedly prompt the user until the input meets the required conditions.
        This makes the program more user-friendly and robust because it doesn't terminate abruptly on invalid input.

    3. Error Handling:
        Users often make mistakes while entering data (e.g., typing numbers in a name field). The loop gives them multiple chances to correct their input.

    4. Seamless Flow:
        The loop ensures the program only proceeds to the next step when the current input is valid, maintaining logical flow and preventing crashes or incorrect outputs.

    5. Mandatory Input:
        For fields like firstName and lastName, valid input is mandatory. The loop ensures these fields are not left blank or filled with invalid data.

    What is the Use of "continue"?

    1. The continue statement is used to skip the rest of the code in the current iteration of the loop and start the next iteration immediately. In the context of this program:
    
    How continue Works Here:

    1. Validation Failure:
        If the user enters invalid data (e.g., a name with numbers), the program prints an error message.
        The continue statement ensures the program skips the rest of the code in the loop and goes back to the beginning of the loop to prompt the user again.

    2. Prevents Execution of Subsequent Code:
        Without continue, the program might attempt to execute code that depends on valid input, leading to unintended behavior or errors.

    Why Use "while True" and "continue" Together?

    1. Infinite Loop with Controlled Exit:
        The while True loop creates an infinite loop, but valid input (or user action) determines when the loop exits using a break.

    2. Error Recovery:
        The continue statement allows the program to recover gracefully from invalid input by restarting the loop instead of executing unnecessary or invalid code.

    3. Logical Flow:
        Combining these two ensures the program enforces strict input validation while maintaining a logical and clean flow.

# %%
#with "if not", "not" and "and", and this is erronous code 
def fullName():
    """
    Combines a first name, optional middle name, and last name into a full name.

    Prompts the user for input until valid data is provided.

    Returns:
    str: The full name in the format 'FirstName MiddleName LastName' or 'FirstName LastName'.
    """
    while True:
        # Prompt for first name
        firstName = input("Enter your first name: ").strip()
        if not firstName.replace(' ', '').alpha() or not firstName.strip(): # allows space between names and handle empty input 
            print("Error: First name must only contain letters. Please try again.")
            continue

        # Prompt for last name
        lastName = input("Enter your last name: ").strip()
        if not lastName.replace(' ', '').alpha() or not lastName.strip(): # allows space between names and handle empty input
            print("Error: Last name must only contain letters. Please try again.")
            continue

        # Prompt for middle name (optional)
        middleName = input("Enter your middle name (leave blank if none): ").strip()
        if middleName and not middleName.replace(' ', '').alpha() or not middleName.strip():
            print("Error: Middle name must only contain letters. Please try again.")
            continue

        # If all inputs are valid, construct and return the full name
        if middleName:
            return f"{firstName} {middleName} {lastName}"
        return f"{firstName} {lastName}"


# Example Usage
print("Please provide your full name.")
full_name = fullName()
print(f"Your full name is: {full_name}")

# %%
    """
    EXPLANATION TO THE CODE ABOVE:

    Errors and Issues in the Code

The code has a logical error in the validation conditions for firstName, lastName, and middleName. Specifically, the condition:

    if not firstName.replace(' ', '').alpha() and firstName.strip():

is incorrect because it combines not with a logical and in a way that doesn't make sense for the intended validation. Let’s break this down:

    not firstName.replace(' ', '').alpha():
        This checks if the string contains anything other than letters and spaces. This part is fine.

    and firstName.strip():
        This checks if the input is not empty after stripping whitespace. However, combining this with the not condition using and creates a conflict:
            If firstName is valid, the condition evaluates to False because of not.
            If firstName is invalid, the condition might still evaluate incorrectly due to the and.

Correcting the Validation Logic

To fix the issue, you should use "or" instead of "and":

    if not firstName.replace(' ', '').isalpha() or not firstName.strip():

This ensures that:

    The condition is True if the input contains non-letter characters (not isalpha()).
    The condition is also True if the input is empty (not strip()).
    The loop will only proceed if both checks are False (i.e., the input is valid).

Why is "not" Compatible with ".replace"?

The "not" operator is fully compatible with ".replace" because:

    .replace() returns a new string, and you can call .isalpha() on it to check if it contains only letters.
    The not operator simply negates the result of .isalpha(), which is a boolean (True or False).

What Does "if not" Do?

The "if not" statement negates the condition following it:

    If the condition evaluates to True, not makes it False.
    If the condition evaluates to False, not makes it True.

Example:

if not True:  # Negates True, so this block won't execute
    print("This won't print.")

if not False:  # Negates False, so this block will execute
    print("This will print.")

In the context of the code:

if not firstName.replace(' ', '').isalpha():

    firstName.replace(' ', '').isalpha() checks if the name contains only letters (and spaces are ignored).
    not negates this:
        If the name is valid (contains only letters), the condition becomes False.
        If the name is invalid (contains non-letters), the condition becomes True.

        """

# %%
# THE CORRECT CODE FOR ABOVE:
def fullName():
    """
    Combines a first name, optional middle name, and last name into a full name.

    Prompts the user for input until valid data is provided.

    Returns:
    str: The full name in the format 'FirstName MiddleName LastName' or 'FirstName LastName'.
    """
    while True:
        # Prompt for first name
        firstName = input("Enter your first name: ").strip()
        if not firstName.replace(' ', '').isalpha() or not firstName.strip():
            print("Error: First name must only contain letters and cannot be empty. Please try again.")
            continue

        # Prompt for last name
        lastName = input("Enter your last name: ").strip()
        if not lastName.replace(' ', '').isalpha() or not lastName.strip():
            print("Error: Last name must only contain letters and cannot be empty. Please try again.")
            continue

        # Prompt for middle name (optional)
        middleName = input("Enter your middle name (leave blank if none): ").strip()
        if middleName and (not middleName.replace(' ', '').isalpha() or not middleName.strip()):
            print("Error: Middle name must only contain letters. Please try again.")
            continue

        # If all inputs are valid, construct and return the full name
        if middleName:
            return f"{firstName} {middleName} {lastName}"
        return f"{firstName} {lastName}"


# Example Usage
print("Please provide your full name.")
full_name = fullName()
print(f"Your full name is: {full_name}")


    """
    Key Changes and Explanations

    Validation Logic:
        Changed "and" to "or" in the validation conditions to correctly check for invalid inputs.

    not Usage:
        Used not to ensure the loop continues if the input is invalid.

    Clearer Error Messages:
        Improved error messages to make them more user-friendly and specific.
    
    """

# %%
#another exercise

def get_customer_name():
        return input('Enter your name: ')

def add_items(item1, item2):
    return item1 + item2

def all_total(name, total_amount):
    print (f'Congratualtions {name}! Your total purrchased amount is ${total_amount} dollar.')

customer_name = get_customer_name()
item1_price = float(input('Enter first item price: '))
item2_price = float(input('Enter second item price: '))

total = add_items(item1_price, item2_price)
all_total(customer_name, total)
# Out:
# Enter your name:  123123
# Enter first item price:  23
# Enter second item price:  123
# Congratualtions 123123! Your total purrchased amount is $146.0 dollar.

# %%
# enhanced code by chatgpt

def add_items(item1, item2):
    """
    Adds two item prices together.
    """
    return item1 + item2

def all_total(name, total_amount):
    """
    Prints a congratulatory message with the total amount.
    """
    if total_amount == 1:
        dollar_text = "dollar"
    else:
        dollar_text = "dollars"
    print(f"Congratulations {name}! Your total purchased amount is ${total_amount:.2f} {dollar_text}.")

def get_customer_name():
    """
    Prompts the user to enter their name.
    """
    while True:
        name = input("Enter your name: ").strip()
        if name.isalpha():  # Ensures the name only contains letters
            return name
        print("Error: Name must only contain letters. Please try again.")

def get_price(prompt):
    """
    Prompts the user to enter a price and ensures it's a valid number.
    """
    while True:
        try:
            price = float(input(prompt))
            if price < 0:
                print("Error: Price cannot be negative. Please try again.")
                continue
            return price
        except ValueError:
            print("Error: Please enter a valid number.")

# Main Program
customer_name = get_customer_name()
item1_price = get_price("Enter first item price: ")
item2_price = get_price("Enter second item price: ")

# total = 0
# for i in range(1, 11):
#     total += get_price(f"Enter price for item {i}: ")
# print(f"The total price for 10 items is ${total:.2f}.")


total = add_items(item1_price, item2_price)
all_total(customer_name, total)
# Out:
# Enter your name:  WER
# Enter first item price:  2
# Enter second item price:  4
# Congratulations WER! Your total purchased amount is $6.00 dollars.

# %% [raw]
# NOTES FOR ABOVE REVISED CODE:
#
# ### 1. **What is the Use of `continue` in the `get_price()` Function?**
#
# The `continue` statement is used to skip the rest of the code inside the loop for the current iteration and move to the next iteration.
#
# In the `get_price()` function:
#
# ```python
# if price < 0:
#     print("Error: Price cannot be negative. Please try again.")
#     continue
# ```
#
# - If the user enters a negative price, the `continue` statement skips the rest of the loop and prompts the user again.
# - Without `continue`, the loop would proceed to the `return` statement, which would end the function and return an invalid value.
#
# ---
#
# ### 2. **Difference Between `continue` and `break`**
#
# | Feature       | `continue`                                   | `break`                                   |
# |---------------|----------------------------------------------|-------------------------------------------|
# | **Purpose**   | Skips the rest of the current loop iteration and moves to the next iteration. | Exits the loop entirely, stopping further iterations. |
# | **Use Case**  | When you want to skip certain inputs or conditions but continue looping. | When you want to stop the loop completely because a condition is met. |
#
# #### Example of `continue`:
# ```python
# for i in range(5):
#     if i == 2:
#         continue  # Skip the rest of the loop for i = 2
#     print(i)
#
# # Output:
# # 0
# # 1
# # 3
# # 4
# ```
#
# #### Example of `break`:
# ```python
# for i in range(5):
#     if i == 2:
#         break  # Exit the loop when i = 2
#     print(i)
#
# # Output:
# # 0
# # 1
# ```
#
# ---
#
# ### 3. **Why Are `price1` and `price2` Handled Separately in the Main Program?**
#
# #### **a. Flexibility and Reusability**
# The `get_price()` function is designed to be generic and reusable. It asks for a single price and ensures it is valid. Separating the logic into the main program allows you to:
#
# - Call `get_price()` as many times as needed for different items.
# - Avoid hardcoding specific variables like `price1` and `price2` into the function.
#
# #### **b. Separation of Concerns**
# - **Function Responsibility**: The `get_price()` function is responsible only for validating and returning a single price.
# - **Main Program Responsibility**: The main program is responsible for combining multiple calls to `get_price()` and handling specific business logic, like summing the prices.
#
# This adheres to the **Single Responsibility Principle**, a key concept in clean code.
#
# #### **c. Example of Why This Separation Is Useful**
# If tomorrow you need to calculate prices for 10 items instead of 2, you can reuse `get_price()` without modifying it.
#
# ```python
# total = 0
# for i in range(1, 11):
#     total += get_price(f"Enter price for item {i}: ")
# print(f"The total price for 10 items is ${total:.2f}.")
# ```
#
# If `get_price()` was tied to `price1` and `price2`, you would have to rewrite the function to accommodate more items.
#
# ---
#
# ### 4. **Advantages of Separating `get_price()`**
#
# 1. **Modularity**:
#    - The function does one thing: validates and returns a single price.
#    - The main program handles combining multiple prices.
#
# 2. **Scalability**:
#    - You can easily extend the program to handle more items without modifying the function.
#
# 3. **Readability**:
#    - Separating the logic makes it easier to understand what each part of the code is doing.
#
# 4. **Reusability**:
#    - The `get_price()` function can be reused in other parts of the program or other programs without changes.
#
# ---
#
# ### 5. **Summary of Design Decisions**
#
# - **Use of `continue`**: Ensures the loop skips invalid inputs and prompts the user again.
# - **Difference Between `continue` and `break`**:
#   - `continue` skips the current iteration; `break` exits the loop entirely.
# - **Why Separate `price1` and `price2`?**:
#   - To keep the `get_price()` function reusable, modular, and focused on validating a single price.
#   - To follow clean coding principles like the Single Responsibility Principle.
#
# This approach makes the program cleaner, easier to extend, and less prone to errors.

# %%
#REVISED CODE WITH 10 ITEMS:


def get_price(prompt):
    """
    Prompts the user to input a valid price.

    Parameters:
    prompt (str): The message displayed to the user.

    Returns:
    float: A valid price entered by the user.
    """
    while True:
        try:
            price = float(input(prompt).strip())
            if price < 0:
                print("Error: Price cannot be negative. Please try again.")
                continue
            return price
        except ValueError:
            print("Error: Please enter a valid number.")

def get_customer_name():
    """
    Prompts the user to input a valid name.

    Returns:
    str: The customer's name.
    """
    while True:
        name = input("Enter your name: ").strip()
        if name.isalpha():
            return name
        else:
            print("Error: Name must only contain letters. Please try again.")

def main():
    """
    Main program to calculate the total price of 10 items and display a personalized message.
    """
    # Prompt for the customer's name
    customer_name = get_customer_name()

    total = 0  # Initialize total to 0

    # Loop to get the price for 10 items
    for i in range(1, 11):  # Loop from 1 to 10
        price = get_price(f"Enter price for item {i}: ")
        total += price  # Add the price to the total

    # Display the personalized total amount
    print(f"\nCongratulations {customer_name}! Your total purchased amount is ${total:.2f}.")

# Run the main program
if __name__ == "__main__":
    main()
# Out:
# Enter your name:  wqeqwe
# Enter price for item 1:  1
# Enter price for item 2:  2
# Enter price for item 3:  3
# Enter price for item 4:  4
# Enter price for item 5:  32
# Enter price for item 6:  2
# Enter price for item 7:  3
# Enter price for item 8:  2
# Enter price for item 9:  12
# Enter price for item 10:  3
# Congratulations wqeqwe! Your total purchased amount is $64.00.

# %% [raw]
# Explanation of Changes for the above code:
#
#     Added get_customer_name() Function:
#         Prompts the user for their name.
#         Validates that the name contains only letters using .isalpha().
#         Loops until a valid name is provided.
#
#     main() Function:
#         First prompts for the customer's name using get_customer_name().
#         Then uses the loop to prompt for prices of 10 items.
#         Combines the customer's name and total price in the final message.
#
#     Personalized Message:
#         After calculating the total, the program prints a message that includes the customer's name and total amount.

# %% [raw]
# ### Why Use `return` Instead of `print` in Functions?
#
# #### Key Reasons:
#
# 1. **Separation of Concerns**:
#    - A function should focus on a **single responsibility**.
#    - `greet(name)` is responsible for creating and returning a greeting message. It shouldn't decide how the message is displayed. This separation allows flexibility in how the function's output is used (e.g., logging, displaying, or further processing).
#
# 2. **Reusability**:
#    - By using `return`, the function's output can be used in different contexts:
#      ```python
#      message = greet('Michael')
#      print(message)  # Display to the user
#      log_to_file(message)  # Save to a log file
#      send_email(message)  # Use in an email
#      ```
#    - If `print` were used directly in the function, its output would be limited to being displayed on the console, making it less versatile.
#
# 3. **Testability**:
#    - Functions that return values are easier to test in automated testing frameworks. For example:
#      ```python
#      def test_greet():
#          assert greet('Michael') == 'Hello Michael! How are you?'
#      ```
#    - If `print` were used, testing would require capturing printed output, which is less straightforward and less clean.
#
# 4. **Clean Code Principles**:
#    - Functions should do one thing and do it well. Returning a value aligns with the **Single Responsibility Principle (SRP)**.
#    - Printing is a side effect that couples the function to a specific output medium (the console). Clean code avoids unnecessary side effects.
#
# ---
#
# ### When to Use `print` in a Function?
#
# - Use `print` only in functions specifically designed for user interaction, such as:
#   ```python
#   def display_greeting():
#       print("Hello, welcome to our application!")
#   ```
# - Even in such cases, consider separating the logic (returning a message) from the presentation (printing it).
#
# ---
#
# ### Best Practices for Defining Functions in Clean Code
#
# 1. **Use Meaningful Names**:
#    - Function names should clearly indicate their purpose.
#      ```python
#      def generate_greeting(name):  # Clear and descriptive
#      ```
#
# 2. **Single Responsibility**:
#    - A function should do one thing only.
#      ```python
#      def calculate_area(radius):  # Only calculates the area
#          return 3.14 * radius ** 2
#      ```
#
# 3. **Avoid Side Effects**:
#    - Side effects like printing or modifying global variables should be minimized or avoided in general-purpose functions.
#
# 4. **Document the Function**:
#    - Include a docstring to describe the purpose, parameters, and return value.
#      ```python
#      def greet(name):
#          """
#          Generates a greeting message.
#
#          Parameters:
#          name (str): The name of the person to greet.
#
#          Returns:
#          str: A greeting message.
#          """
#          return f"Hello {name}!"
#      ```
#
# 5. **Keep It Short**:
#    - A function should ideally fit within 20-30 lines of code. If it grows larger, consider breaking it into smaller functions.
#
# 6. **Handle Errors Gracefully**:
#    - Validate inputs and raise meaningful errors when necessary.
#      ```python
#      def greet(name):
#          if not isinstance(name, str) or not name.strip():
#              raise ValueError("Name must be a non-empty string.")
#          return f"Hello {name.strip()}!"
#      ```
#
# ---
#
# ### Example: Clean Code Version
#
# ```python
# def greet(name):
#     """
#     Generates a greeting message.
#
#     Parameters:
#     name (str): The name of the person to greet.
#
#     Returns:
#     str: A greeting message.
#     """
#     if not isinstance(name, str) or not name.strip():
#         raise ValueError("Name must be a non-empty string.")
#     return f"Hello {name.strip()}!"
#
# # Main Program
# try:
#     user_name = input("What is your name? ").strip()
#     print(greet(user_name))
# except ValueError as e:
#     print(e)
# ```
#
# ---
#
# ### Key Takeaways
#
# - Use `return` in functions to make them reusable, testable, and clean.
# - Reserve `print` for user-facing interactions or debugging.
# - Following clean code principles ensures your code is maintainable, readable, and scalable.
